# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow import keras
import keras.ops as ops
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score, classification_report, confusion_matrix


print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.21.0

# %%
T          = 36     
C          = 10     
D_MODEL    = 64     
N_HEADS    = 5     
N_STAGES   = 3      
KERNEL     = 3      
DROPOUT    = 0.1
BATCH_SIZE = 32
EPOCHS     = 200
LR         = 1e-3

N_CLASSES_AR = 5
N_CLASSES_CA = 6

# %%
BANDS = ['B2','B3','B4','B5','B6','B7','B8','B8A','B11','B12']

AR_LABEL_MAP = {1:0, 2:1, 3:2, 5:3, 99:4}   # Corn, Cotton, Rice, Soy, Others
CA_LABEL_MAP = {3:0, 36:1, 69:2, 75:3, 204:4, 99:5}

AR_CLASS_NAMES = ['Corn', 'Cotton', 'Rice', 'Soybeans', 'Others']
CA_CLASS_NAMES = ['Grapes', 'Rice', 'Alfalfa', 'Almonds', 'Pistachios', 'Others']

def load_dataset(csv_path, label_map, n_classes, T=36, train_per_class=240, val_per_class=60, random_seed=42):
    """
    Transforms CSV data into model-ready tensors and performs a balanced split.
    """
    df = pd.read_csv(csv_path)
    df['label'] = df['cropland'].map(label_map)
    df = df.dropna(subset=['label'])
    df['label'] = df['label'].astype(int)

    spectral_cols = [f'{t}_{b}' for t in range(T) for b in BANDS]  
    X = df[spectral_cols].values.astype(np.float32).reshape(-1, T, len(BANDS))

    missing_cols = [f'{t}_missing_{t}' for t in range(T)]  
    M = df[missing_cols].values.astype(np.float32)

    y = df['label'].values

    rng = np.random.default_rng(random_seed)
    tr_idx, vl_idx, te_idx = [], [], []
    for cls in range(n_classes):
        idx = np.where(y == cls)[0]
        rng.shuffle(idx)
        n = len(idx)
        tr_limit = min(train_per_class, n)
        vl_limit = min(val_per_class, n - tr_limit)
        tr_idx.extend(idx[:tr_limit])
        vl_idx.extend(idx[tr_limit:tr_limit + vl_limit])
        te_idx.extend(idx[tr_limit + vl_limit:])

    def get_split(i):
        return X[i], M[i], y[i]

    train = get_split(tr_idx)
    val   = get_split(vl_idx)
    test  = get_split(te_idx)

    print(f"Loaded {csv_path}: Train={len(tr_idx)}, Val={len(vl_idx)}, Test={len(te_idx)}")
    return train, val, test

# %%
def alpe_block(x, mask, d_model, name="alpe"):

    T = ops.shape(x)[1]

    positions = ops.cast(ops.arange(T), "float32")[:, None]
    dims = ops.cast(ops.arange(d_model), "float32")[None, :]

    angles = positions / ops.power(10000.0, (2.0 * (dims // 2)) / ops.cast(d_model, "float32"))
    
    sin_pe = ops.sin(angles[:, 0::2])
    cos_pe = ops.cos(angles[:, 1::2])
    
    pe = ops.stack([sin_pe, cos_pe], axis=-1)
    pe = ops.reshape(pe, [1, T, d_model])

    missing_weight = 1.0 - ops.expand_dims(ops.cast(mask, "float32"), -1)
    pe = pe * missing_weight

    pe = keras.layers.Conv1D(d_model, 3, padding='same', use_bias=False, name=f"{name}_conv")(pe)
    pe = keras.layers.BatchNormalization(name=f"{name}_bn")(pe)

    gap = ops.mean(pe, axis=1, keepdims=True)
    weights = keras.layers.Conv1D(d_model, 1, padding='same', activation='sigmoid', name=f"{name}_eca")(gap)
    pe = pe * weights

    return pe

# %%
def cnn_sub_module(x, d_model, kernel_size=3, name="cnn"):

    residual = layers.Conv1D(d_model, 1, padding='same', use_bias=False)(x)
    
    out = layers.Conv1D(d_model, kernel_size, padding='same', use_bias=False)(x)
    out = layers.BatchNormalization()(out)
    out = layers.Activation('relu')(out)
    
    out = layers.Conv1D(d_model, kernel_size, padding='same', use_bias=False)(out)
    out = layers.BatchNormalization()(out)
    
    out = layers.Activation('relu')(out + residual)
    return out

def transformer_sub_module(x, d_model, n_heads, dropout=0.1, name="trans"):
    attn_out = layers.MultiHeadAttention(num_heads=n_heads, key_dim=d_model//n_heads)(x, x)
    attn_out = layers.Dropout(dropout)(attn_out)
    x = layers.LayerNormalization(epsilon=1e-6)(x + attn_out)

    ffn_out = layers.Dense(d_model * 4, activation='relu')(x)
    ffn_out = layers.Dense(d_model)(ffn_out)
    ffn_out = layers.Dropout(dropout)(ffn_out)
    x = layers.LayerNormalization(epsilon=1e-6)(x + ffn_out)
    return x

# %%
def sinusoidal_pe(x, d_model):
    T_sym  = ops.shape(x)[1]
    pos    = ops.cast(ops.arange(T_sym), 'float32')[:, None]
    dims   = ops.cast(ops.arange(d_model), 'float32')[None, :]
    angles = pos / ops.power(10000.0,
                 (2.0 * (dims // 2)) / ops.cast(d_model, 'float32'))
    sin_pe = ops.sin(angles[:, 0::2])
    cos_pe = ops.cos(angles[:, 1::2])
    pe = ops.reshape(ops.stack([sin_pe, cos_pe], axis=-1), [1, T_sym, d_model])
    return pe  


def build_mctnet_functional(n_classes, T=36, C=10, d_model=64,
                             n_heads=5, n_stages=3, kernel_size=3, dropout=0.1):

    spectral_in = layers.Input(shape=(T, C),  name='spectral')
    mask_in     = layers.Input(shape=(T,),    name='mask')

    x = layers.Dense(d_model, use_bias=False, name='input_proj')(spectral_in)

    for i in range(n_stages):
        if i == 0:
            pe = alpe_block(x, mask_in, d_model, name=f'stage{i}_alpe')
        else:
            pe = sinusoidal_pe(x, d_model)

        x_pe = x + pe

        cnn_path   = cnn_sub_module(x,    d_model, kernel_size, name=f'stage{i}_cnn')
        trans_path = transformer_sub_module(x_pe, d_model, n_heads,
                                            dropout=dropout, name=f'stage{i}_trans')

        fused = layers.Concatenate(name=f'stage{i}_concat')([cnn_path, trans_path])
        fused = layers.Dense(d_model, use_bias=False, name=f'stage{i}_proj')(fused)
        x     = layers.MaxPooling1D(pool_size=2, padding='same',
                                    name=f'stage{i}_pool')(fused)


    x      = layers.GlobalMaxPooling1D(name='global_maxpool')(x)
    x      = layers.Dropout(dropout, name='head_dropout')(x)
    output = layers.Dense(n_classes, activation='softmax', name='classifier')(x)

    return keras.Model(inputs=[spectral_in, mask_in],
                       outputs=output, name='MCTNet')

model = build_mctnet_functional(n_classes=N_CLASSES_AR)

# %%
def build_parmctnet_functional(n_classes, T=36, C=10, d_model=64,
                                n_heads=5, n_branches=3,
                                kernels=(3, 5, 7), dropout=0.1):

    spectral_in = layers.Input(shape=(T, C), name='spectral')
    mask_in     = layers.Input(shape=(T,),   name='mask')

    # Shared input projection
    x_proj = layers.Dense(d_model, use_bias=False, name='input_proj')(spectral_in)

    branch_outputs = []

    for i in range(n_branches):
        k = kernels[i] if i < len(kernels) else 3
        bname = f'branch{i}'

        if i == 0:
            pe = alpe_block(x_proj, mask_in, d_model, name=f'{bname}_alpe')
        else:
            pe = sinusoidal_pe(x_proj, d_model)

        x_pe = x_proj + pe   

        cnn_out   = cnn_sub_module(x_proj, d_model, kernel_size=k,
                                   name=f'{bname}_cnn')
        trans_out = transformer_sub_module(x_pe, d_model, n_heads,
                                           dropout=dropout,
                                           name=f'{bname}_trans')

        fused = layers.Concatenate(name=f'{bname}_concat')([cnn_out, trans_out])
        fused = layers.Dense(d_model, use_bias=False,
                             name=f'{bname}_proj')(fused)

        pooled = layers.GlobalMaxPooling1D(name=f'{bname}_gmp')(fused)
        branch_outputs.append(pooled)

    if n_branches == 1:
        merged = branch_outputs[0]
    else:
        merged = layers.Concatenate(name='branch_merge')(branch_outputs)

        merged = layers.Dense(d_model, activation='relu',
                              name='merge_proj')(merged)

    x      = layers.Dropout(dropout, name='head_dropout')(merged)
    output = layers.Dense(n_classes, activation='softmax',
                          name='classifier')(x)

    return keras.Model(inputs=[spectral_in, mask_in],
                       outputs=output, name='ParMCTNet')

par_model = build_parmctnet_functional(n_classes=N_CLASSES_AR)
seq_model = build_mctnet_functional(n_classes=N_CLASSES_AR)

# %%
def compile_and_train(model, train, val, lr=1e-3, epochs=200, batch_size=32):

    X_tr, M_tr, y_tr = train
    X_vl, M_vl, y_vl = val

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr, clipnorm =1.0),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    callbacks = [
        keras.callbacks.EarlyStopping(
            monitor='val_loss', patience=20, restore_best_weights=True
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6
        ),
    ]

    history = model.fit(
        x={'spectral': X_tr, 'mask': M_tr},
        y=y_tr,
        validation_data=({'spectral': X_vl, 'mask': M_vl}, y_vl),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=1
    )
    return history


train_ar, val_ar, test_ar = load_dataset(r"D:\compressed\neur net\arkansas.csv", AR_LABEL_MAP, N_CLASSES_AR)
train_ca, val_ca, test_ca = load_dataset(r"D:\compressed\neur net\california.csv", CA_LABEL_MAP, N_CLASSES_CA)
model_ar = build_mctnet_functional(n_classes=N_CLASSES_AR)
model_ca = build_mctnet_functional(n_classes=N_CLASSES_CA)
history_ar = compile_and_train(model_ar, train_ar, val_ar,lr=LR, epochs=EPOCHS, batch_size=BATCH_SIZE)
history_ca = compile_and_train(model_ca, train_ca, val_ca,lr=LR, epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Loaded D:\compressed\neur net\arkansas.csv: Train=1200, Val=300, Test=8500
# Loaded D:\compressed\neur net\california.csv: Train=1440, Val=360, Test=8200
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.5267 - loss: 1.2364 - val_accuracy: 0.2000 - val_loss: 2.1833 - learning_rate: 0.0010
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8467 - loss: 0.4461 - val_accuracy: 0.2000 - val_loss: 3.0721 - learning_rate: 0.0010
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9033 - loss: 0.2670 - val_accuracy: 0.2000 - val_loss: 5.2525 - learning_rate: 0.0010
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9033 - loss: 0.2686 - val_accuracy: 0.2000 - val_loss: 5.3208 - learning_rate: 0.0010
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9283 - loss: 0.2076 - val_accuracy: 0.3000 - val_loss: 3.5886 - learning_rate: 0.0010
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9600 - loss: 0.1163 - val_accuracy: 0.2000 - val_loss: 5.7405 - learning_rate: 0.0010
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9558 - loss: 0.1465 - val_accuracy: 0.2000 - val_loss: 5.9640 - learning_rate: 0.0010
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9575 - loss: 0.1210 - val_accuracy: 0.3033 - val_loss: 5.1055 - learning_rate: 0.0010
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9475 - loss: 0.1431 - val_accuracy: 0.3233 - val_loss: 3.5546 - learning_rate: 0.0010
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9700 - loss: 0.0961 - val_accuracy: 0.4600 - val_loss: 2.9190 - learning_rate: 0.0010
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9700 - loss: 0.0764 - val_accuracy: 0.7600 - val_loss: 0.7815 - learning_rate: 0.0010
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9783 - loss: 0.0680 - val_accuracy: 0.8467 - val_loss: 0.5318 - learning_rate: 0.0010
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9625 - loss: 0.1115 - val_accuracy: 0.7767 - val_loss: 0.7911 - learning_rate: 0.0010
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9767 - loss: 0.0653 - val_accuracy: 0.9167 - val_loss: 0.2995 - learning_rate: 0.0010
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9808 - loss: 0.0455 - val_accuracy: 0.8900 - val_loss: 0.3633 - learning_rate: 0.0010
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9883 - loss: 0.0451 - val_accuracy: 0.8333 - val_loss: 0.6844 - learning_rate: 0.0010
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9850 - loss: 0.0505 - val_accuracy: 0.9333 - val_loss: 0.2742 - learning_rate: 0.0010
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9900 - loss: 0.0319 - val_accuracy: 0.9067 - val_loss: 0.2768 - learning_rate: 0.0010
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9783 - loss: 0.0600 - val_accuracy: 0.9433 - val_loss: 0.2142 - learning_rate: 0.0010
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9842 - loss: 0.0411 - val_accuracy: 0.9033 - val_loss: 0.3581 - learning_rate: 0.0010
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9933 - loss: 0.0305 - val_accuracy: 0.9433 - val_loss: 0.1985 - learning_rate: 0.0010
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9833 - loss: 0.0512 - val_accuracy: 0.8500 - val_loss: 0.5821 - learning_rate: 0.0010
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9733 - loss: 0.0761 - val_accuracy: 0.8433 - val_loss: 0.5478 - learning_rate: 0.0010
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9758 - loss: 0.0648 - val_accuracy: 0.9400 - val_loss: 0.2455 - learning_rate: 0.0010
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9850 - loss: 0.0473 - val_accuracy: 0.8367 - val_loss: 0.7441 - learning_rate: 0.0010
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9825 - loss: 0.0524 - val_accuracy: 0.9367 - val_loss: 0.2417 - learning_rate: 0.0010
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9767 - loss: 0.0640 - val_accuracy: 0.9167 - val_loss: 0.3173 - learning_rate: 0.0010
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9892 - loss: 0.0310 - val_accuracy: 0.9367 - val_loss: 0.2748 - learning_rate: 0.0010
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9842 - loss: 0.0471 - val_accuracy: 0.9167 - val_loss: 0.3252 - learning_rate: 0.0010
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9883 - loss: 0.0300 - val_accuracy: 0.9300 - val_loss: 0.3127 - learning_rate: 0.0010
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9950 - loss: 0.0200 - val_accuracy: 0.8867 - val_loss: 0.4130 - learning_rate: 0.0010
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9967 - loss: 0.0142 - val_accuracy: 0.9267 - val_loss: 0.3414 - learning_rate: 5.0000e-04
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9992 - loss: 0.0042 - val_accuracy: 0.9333 - val_loss: 0.3242 - learning_rate: 5.0000e-04
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9333 - val_loss: 0.3035 - learning_rate: 5.0000e-04
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9300 - val_loss: 0.3101 - learning_rate: 5.0000e-04
# Epoch 36/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9333 - val_loss: 0.3019 - learning_rate: 5.0000e-04
# Epoch 37/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9367 - val_loss: 0.3091 - learning_rate: 5.0000e-04
# Epoch 38/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9333 - val_loss: 0.3115 - learning_rate: 5.0000e-04
# Epoch 39/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9975 - loss: 0.0041 - val_accuracy: 0.9333 - val_loss: 0.2764 - learning_rate: 5.0000e-04
# Epoch 40/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9992 - loss: 0.0019 - val_accuracy: 0.9267 - val_loss: 0.3122 - learning_rate: 5.0000e-04
# Epoch 41/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 9.3820e-04 - val_accuracy: 0.9367 - val_loss: 0.2839 - learning_rate: 5.0000e-04
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - accuracy: 0.6236 - loss: 1.0622 - val_accuracy: 0.2611 - val_loss: 2.1907 - learning_rate: 0.0010
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8007 - loss: 0.5648 - val_accuracy: 0.3389 - val_loss: 2.2977 - learning_rate: 0.0010
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8465 - loss: 0.4635 - val_accuracy: 0.1694 - val_loss: 3.2746 - learning_rate: 0.0010
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8847 - loss: 0.3328 - val_accuracy: 0.2139 - val_loss: 2.8898 - learning_rate: 0.0010
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8931 - loss: 0.3084 - val_accuracy: 0.3889 - val_loss: 2.8641 - learning_rate: 0.0010
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9201 - loss: 0.2431 - val_accuracy: 0.4278 - val_loss: 1.8309 - learning_rate: 0.0010
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9153 - loss: 0.2409 - val_accuracy: 0.5667 - val_loss: 1.1719 - learning_rate: 0.0010
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9299 - loss: 0.2080 - val_accuracy: 0.4639 - val_loss: 1.8683 - learning_rate: 0.0010
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9368 - loss: 0.1871 - val_accuracy: 0.6889 - val_loss: 0.9765 - learning_rate: 0.0010
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9340 - loss: 0.1903 - val_accuracy: 0.8222 - val_loss: 0.5154 - learning_rate: 0.0010
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9521 - loss: 0.1569 - val_accuracy: 0.8500 - val_loss: 0.5022 - learning_rate: 0.0010
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9563 - loss: 0.1237 - val_accuracy: 0.9028 - val_loss: 0.3452 - learning_rate: 0.0010
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9590 - loss: 0.1156 - val_accuracy: 0.9083 - val_loss: 0.3210 - learning_rate: 0.0010
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9479 - loss: 0.1433 - val_accuracy: 0.8972 - val_loss: 0.3470 - learning_rate: 0.0010
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9653 - loss: 0.1046 - val_accuracy: 0.8528 - val_loss: 0.5101 - learning_rate: 0.0010
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9597 - loss: 0.1094 - val_accuracy: 0.9111 - val_loss: 0.3302 - learning_rate: 0.0010
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9736 - loss: 0.0767 - val_accuracy: 0.9028 - val_loss: 0.3343 - learning_rate: 0.0010
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9674 - loss: 0.0835 - val_accuracy: 0.9083 - val_loss: 0.2974 - learning_rate: 0.0010
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9792 - loss: 0.0551 - val_accuracy: 0.9167 - val_loss: 0.3612 - learning_rate: 0.0010
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9840 - loss: 0.0566 - val_accuracy: 0.9028 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9701 - loss: 0.0896 - val_accuracy: 0.9083 - val_loss: 0.3658 - learning_rate: 0.0010
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9819 - loss: 0.0640 - val_accuracy: 0.9222 - val_loss: 0.3503 - learning_rate: 0.0010
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9812 - loss: 0.0532 - val_accuracy: 0.9333 - val_loss: 0.2752 - learning_rate: 0.0010
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9924 - loss: 0.0288 - val_accuracy: 0.9028 - val_loss: 0.3274 - learning_rate: 0.0010
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9903 - loss: 0.0259 - val_accuracy: 0.9167 - val_loss: 0.3559 - learning_rate: 0.0010
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9910 - loss: 0.0278 - val_accuracy: 0.9306 - val_loss: 0.3067 - learning_rate: 0.0010
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9882 - loss: 0.0346 - val_accuracy: 0.8944 - val_loss: 0.4297 - learning_rate: 0.0010
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9931 - loss: 0.0291 - val_accuracy: 0.9139 - val_loss: 0.4074 - learning_rate: 0.0010
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9861 - loss: 0.0406 - val_accuracy: 0.9139 - val_loss: 0.4239 - learning_rate: 0.0010
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9868 - loss: 0.0405 - val_accuracy: 0.9278 - val_loss: 0.3203 - learning_rate: 0.0010
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9931 - loss: 0.0216 - val_accuracy: 0.9278 - val_loss: 0.3660 - learning_rate: 0.0010
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9826 - loss: 0.0517 - val_accuracy: 0.9111 - val_loss: 0.3246 - learning_rate: 0.0010
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9792 - loss: 0.0614 - val_accuracy: 0.9056 - val_loss: 0.4419 - learning_rate: 0.0010
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9924 - loss: 0.0243 - val_accuracy: 0.9250 - val_loss: 0.2958 - learning_rate: 5.0000e-04
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9993 - loss: 0.0061 - val_accuracy: 0.9333 - val_loss: 0.2929 - learning_rate: 5.0000e-04
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9361 - val_loss: 0.3017 - learning_rate: 5.0000e-04
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9389 - val_loss: 0.2981 - learning_rate: 5.0000e-04
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9389 - val_loss: 0.3013 - learning_rate: 5.0000e-04
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9361 - val_loss: 0.2940 - learning_rate: 5.0000e-04
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9389 - val_loss: 0.3141 - learning_rate: 5.0000e-04
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 0.9361 - val_loss: 0.3365 - learning_rate: 5.0000e-04
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9361 - val_loss: 0.3237 - learning_rate: 5.0000e-04
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9361 - val_loss: 0.3402 - learning_rate: 5.0000e-04

# %%
par_model_ar = build_parmctnet_functional(n_classes=N_CLASSES_AR)
history_par_ar = compile_and_train(par_model_ar, train_ar, val_ar,
                                   lr=LR, epochs=EPOCHS, batch_size=BATCH_SIZE)


par_model_ca = build_parmctnet_functional(n_classes=N_CLASSES_CA)
history_par_ca = compile_and_train(par_model_ca, train_ca, val_ca,
                                   lr=LR, epochs=EPOCHS, batch_size=BATCH_SIZE)


def evaluate_model(model, test, class_names, model_name):
    X_te, M_te, y_te = test
    y_pred = model.predict({'spectral': X_te, 'mask': M_te}).argmax(axis=1)
    oa     = accuracy_score(y_te, y_pred)
    kappa  = cohen_kappa_score(y_te, y_pred)
    f1     = f1_score(y_te, y_pred, average='macro')
    print(f"\n{model_name}")
    print(f"  OA={oa:.4f}  Kappa={kappa:.4f}  F1={f1:.4f}")
    print(classification_report(y_te, y_pred, target_names=class_names))
    return oa, kappa, f1

print("=== Arkansas ===")
evaluate_model(model_ar,     test_ar, AR_CLASS_NAMES, "Sequential MCTNet")
evaluate_model(par_model_ar, test_ar, AR_CLASS_NAMES, "Parallel ParMCTNet")

print("=== California ===")
evaluate_model(model_ca,     test_ca, CA_CLASS_NAMES, "Sequential MCTNet")
evaluate_model(par_model_ca, test_ca, CA_CLASS_NAMES, "Parallel ParMCTNet")


fig, axes = plt.subplots(2, 2, figsize=(14, 8))
for row, (h_seq, h_par, ds) in enumerate([
        (history_ar, history_par_ar, 'Arkansas'),
        (history_ca, history_par_ca, 'California')]):
    axes[row,0].plot(h_seq.history['val_loss'], label='Sequential')
    axes[row,0].plot(h_par.history['val_loss'], label='Parallel')
    axes[row,0].set_title(f'{ds} — Val Loss'); axes[row,0].legend()
    axes[row,1].plot(h_seq.history['val_accuracy'], label='Sequential')
    axes[row,1].plot(h_par.history['val_accuracy'], label='Parallel')
    axes[row,1].set_title(f'{ds} — Val Accuracy'); axes[row,1].legend()
plt.tight_layout(); plt.show()
# Out:
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - accuracy: 0.4850 - loss: 1.3394 - val_accuracy: 0.2000 - val_loss: 1.7940 - learning_rate: 0.0010
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.7692 - loss: 0.6348 - val_accuracy: 0.3567 - val_loss: 1.9265 - learning_rate: 0.0010
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8642 - loss: 0.3962 - val_accuracy: 0.3000 - val_loss: 2.1156 - learning_rate: 0.0010
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8800 - loss: 0.3240 - val_accuracy: 0.2000 - val_loss: 2.6313 - learning_rate: 0.0010
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9183 - loss: 0.2368 - val_accuracy: 0.2500 - val_loss: 2.4019 - learning_rate: 0.0010
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9283 - loss: 0.2103 - val_accuracy: 0.3733 - val_loss: 2.1271 - learning_rate: 0.0010
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9417 - loss: 0.1702 - val_accuracy: 0.3600 - val_loss: 2.1324 - learning_rate: 0.0010
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9583 - loss: 0.1347 - val_accuracy: 0.4167 - val_loss: 1.6910 - learning_rate: 0.0010
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9675 - loss: 0.1130 - val_accuracy: 0.5300 - val_loss: 1.2906 - learning_rate: 0.0010
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9608 - loss: 0.1048 - val_accuracy: 0.8333 - val_loss: 0.4998 - learning_rate: 0.0010
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9517 - loss: 0.1353 - val_accuracy: 0.7833 - val_loss: 0.7570 - learning_rate: 0.0010
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9575 - loss: 0.1260 - val_accuracy: 0.8900 - val_loss: 0.3803 - learning_rate: 0.0010
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9725 - loss: 0.0875 - val_accuracy: 0.8767 - val_loss: 0.3501 - learning_rate: 0.0010
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9792 - loss: 0.0661 - val_accuracy: 0.8167 - val_loss: 0.6027 - learning_rate: 0.0010
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9733 - loss: 0.0868 - val_accuracy: 0.9333 - val_loss: 0.2214 - learning_rate: 0.0010
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9825 - loss: 0.0549 - val_accuracy: 0.9500 - val_loss: 0.2272 - learning_rate: 0.0010
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9833 - loss: 0.0516 - val_accuracy: 0.8767 - val_loss: 0.4455 - learning_rate: 0.0010
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9808 - loss: 0.0663 - val_accuracy: 0.9300 - val_loss: 0.2279 - learning_rate: 0.0010
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9875 - loss: 0.0507 - val_accuracy: 0.8867 - val_loss: 0.4735 - learning_rate: 0.0010
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9875 - loss: 0.0434 - val_accuracy: 0.9133 - val_loss: 0.3940 - learning_rate: 0.0010
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9825 - loss: 0.0672 - val_accuracy: 0.9000 - val_loss: 0.4260 - learning_rate: 0.0010
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9917 - loss: 0.0316 - val_accuracy: 0.8933 - val_loss: 0.5023 - learning_rate: 0.0010
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9825 - loss: 0.0493 - val_accuracy: 0.9300 - val_loss: 0.2481 - learning_rate: 0.0010
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9933 - loss: 0.0337 - val_accuracy: 0.9100 - val_loss: 0.3822 - learning_rate: 0.0010
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9875 - loss: 0.0347 - val_accuracy: 0.9400 - val_loss: 0.2801 - learning_rate: 0.0010
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9950 - loss: 0.0176 - val_accuracy: 0.9067 - val_loss: 0.3886 - learning_rate: 5.0000e-04
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9908 - loss: 0.0259 - val_accuracy: 0.9367 - val_loss: 0.2251 - learning_rate: 5.0000e-04
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9908 - loss: 0.0253 - val_accuracy: 0.9267 - val_loss: 0.3044 - learning_rate: 5.0000e-04
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9975 - loss: 0.0098 - val_accuracy: 0.9333 - val_loss: 0.3180 - learning_rate: 5.0000e-04
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9967 - loss: 0.0103 - val_accuracy: 0.9467 - val_loss: 0.2846 - learning_rate: 5.0000e-04
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9967 - loss: 0.0085 - val_accuracy: 0.9467 - val_loss: 0.2803 - learning_rate: 5.0000e-04
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9467 - val_loss: 0.2870 - learning_rate: 5.0000e-04
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9992 - loss: 0.0050 - val_accuracy: 0.9500 - val_loss: 0.3150 - learning_rate: 5.0000e-04
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9433 - val_loss: 0.2888 - learning_rate: 5.0000e-04
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9992 - loss: 0.0050 - val_accuracy: 0.9333 - val_loss: 0.2947 - learning_rate: 5.0000e-04
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.6479 - loss: 1.0076 - val_accuracy: 0.1667 - val_loss: 1.8597 - learning_rate: 0.0010
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.8389 - loss: 0.5143 - val_accuracy: 0.4167 - val_loss: 1.7535 - learning_rate: 0.0010
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8708 - loss: 0.3961 - val_accuracy: 0.2444 - val_loss: 1.9651 - learning_rate: 0.0010
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8792 - loss: 0.3725 - val_accuracy: 0.2944 - val_loss: 1.5954 - learning_rate: 0.0010
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9090 - loss: 0.2995 - val_accuracy: 0.4028 - val_loss: 1.5457 - learning_rate: 0.0010
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9201 - loss: 0.2541 - val_accuracy: 0.6611 - val_loss: 0.9823 - learning_rate: 0.0010
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9250 - loss: 0.2271 - val_accuracy: 0.6944 - val_loss: 0.8500 - learning_rate: 0.0010
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9285 - loss: 0.2173 - val_accuracy: 0.7889 - val_loss: 0.6290 - learning_rate: 0.0010
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9431 - loss: 0.1763 - val_accuracy: 0.8000 - val_loss: 0.6257 - learning_rate: 0.0010
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9417 - loss: 0.1766 - val_accuracy: 0.8389 - val_loss: 0.4522 - learning_rate: 0.0010
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9451 - loss: 0.1484 - val_accuracy: 0.9167 - val_loss: 0.3378 - learning_rate: 0.0010
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9542 - loss: 0.1369 - val_accuracy: 0.9000 - val_loss: 0.3157 - learning_rate: 0.0010
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9486 - loss: 0.1465 - val_accuracy: 0.9167 - val_loss: 0.3069 - learning_rate: 0.0010
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9674 - loss: 0.1075 - val_accuracy: 0.9028 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9799 - loss: 0.0826 - val_accuracy: 0.9194 - val_loss: 0.2716 - learning_rate: 0.0010
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9757 - loss: 0.0732 - val_accuracy: 0.9306 - val_loss: 0.2711 - learning_rate: 0.0010
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9792 - loss: 0.0688 - val_accuracy: 0.8917 - val_loss: 0.4174 - learning_rate: 0.0010
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9750 - loss: 0.0692 - val_accuracy: 0.9444 - val_loss: 0.2626 - learning_rate: 0.0010
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9757 - loss: 0.0859 - val_accuracy: 0.8861 - val_loss: 0.3577 - learning_rate: 0.0010
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9715 - loss: 0.0827 - val_accuracy: 0.9167 - val_loss: 0.3208 - learning_rate: 0.0010
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9806 - loss: 0.0750 - val_accuracy: 0.9333 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9743 - loss: 0.0756 - val_accuracy: 0.9139 - val_loss: 0.3648 - learning_rate: 0.0010
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9729 - loss: 0.0782 - val_accuracy: 0.8944 - val_loss: 0.4171 - learning_rate: 0.0010
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9840 - loss: 0.0489 - val_accuracy: 0.9111 - val_loss: 0.3876 - learning_rate: 0.0010
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9799 - loss: 0.0650 - val_accuracy: 0.9389 - val_loss: 0.2516 - learning_rate: 0.0010
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9868 - loss: 0.0429 - val_accuracy: 0.9361 - val_loss: 0.2673 - learning_rate: 0.0010
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9924 - loss: 0.0279 - val_accuracy: 0.9333 - val_loss: 0.2546 - learning_rate: 0.0010
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9903 - loss: 0.0336 - val_accuracy: 0.8944 - val_loss: 0.4161 - learning_rate: 0.0010
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9833 - loss: 0.0388 - val_accuracy: 0.9250 - val_loss: 0.3100 - learning_rate: 0.0010
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9917 - loss: 0.0297 - val_accuracy: 0.9389 - val_loss: 0.2915 - learning_rate: 0.0010
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9910 - loss: 0.0248 - val_accuracy: 0.9389 - val_loss: 0.3018 - learning_rate: 0.0010
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9937 - loss: 0.0226 - val_accuracy: 0.8722 - val_loss: 0.5518 - learning_rate: 0.0010
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9840 - loss: 0.0421 - val_accuracy: 0.9417 - val_loss: 0.3032 - learning_rate: 0.0010
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9861 - loss: 0.0391 - val_accuracy: 0.9333 - val_loss: 0.2957 - learning_rate: 0.0010
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9806 - loss: 0.0476 - val_accuracy: 0.9250 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9937 - loss: 0.0249 - val_accuracy: 0.9361 - val_loss: 0.2801 - learning_rate: 5.0000e-04
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9500 - val_loss: 0.2683 - learning_rate: 5.0000e-04
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9993 - loss: 0.0043 - val_accuracy: 0.9500 - val_loss: 0.2716 - learning_rate: 5.0000e-04
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9472 - val_loss: 0.2842 - learning_rate: 5.0000e-04
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9500 - val_loss: 0.2797 - learning_rate: 5.0000e-04
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9528 - val_loss: 0.2862 - learning_rate: 5.0000e-04
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9528 - val_loss: 0.2818 - learning_rate: 5.0000e-04
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9500 - val_loss: 0.2847 - learning_rate: 5.0000e-04
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9500 - val_loss: 0.2897 - learning_rate: 5.0000e-04
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9528 - val_loss: 0.2779 - learning_rate: 5.0000e-04
# === Arkansas ===
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step
#
# Sequential MCTNet
#   OA=0.9522  Kappa=0.9274  F1=0.9042
#               precision    recall  f1-score   support
#
#         Corn       0.98      0.97      0.98      1222
#       Cotton       0.95      0.97      0.96       462
#         Rice       1.00      0.95      0.97      2123
#     Soybeans       0.98      0.95      0.96      4377
#       Others       0.51      0.89      0.65       316
#
#     accuracy                           0.95      8500
#    macro avg       0.88      0.95      0.90      8500
# weighted avg       0.97      0.95      0.96      8500
#
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
#
# Parallel ParMCTNet
#   OA=0.9389  Kappa=0.9086  F1=0.8957
#               precision    recall  f1-score   support
#
#         Corn       0.89      0.99      0.94      1222
#       Cotton       0.97      0.97      0.97       462
#         Rice       0.98      0.98      0.98      2123
#     Soybeans       0.99      0.90      0.95      4377
#       Others       0.50      0.91      0.64       316
#
#     accuracy                           0.94      8500
#    macro avg       0.87      0.95      0.90      8500
# weighted avg       0.96      0.94      0.94      8500
#
# === California ===
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
#
# Sequential MCTNet
#   OA=0.8909  Kappa=0.8579  F1=0.8738
#               precision    recall  f1-score   support
#
#       Grapes       0.99      0.99      0.99      1737
#         Rice       0.94      0.96      0.95       674
#      Alfalfa       0.95      0.90      0.92      1754
#      Almonds       0.42      0.94      0.58       483
#   Pistachios       0.89      0.94      0.92       340
#       Others       0.97      0.80      0.88      3212
#
#     accuracy                           0.89      8200
#    macro avg       0.86      0.92      0.87      8200
# weighted avg       0.93      0.89      0.90      8200
#
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
#
# Parallel ParMCTNet
#   OA=0.9074  Kappa=0.8785  F1=0.8750
#               precision    recall  f1-score   support
#
#       Grapes       0.99      0.99      0.99      1737
#         Rice       0.83      0.97      0.90       674
#      Alfalfa       0.92      0.94      0.93      1754
#      Almonds       0.64      0.85      0.73       483
#   Pistachios       0.68      0.98      0.80       340
#       Others       0.97      0.83      0.90      3212
#
#     accuracy                           0.91      8200
#    macro avg       0.84      0.93      0.88      8200
# weighted avg       0.92      0.91      0.91      8200
